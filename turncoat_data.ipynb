# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gujrat_from_1980_all = pd.read_csv('Gujarat_AE_from_1980.csv')

# %%
gujrat_from_1980_all.columns
# Out:
# Index(['Election_Type', 'State_Name', 'Assembly_No', 'Constituency_No', 'Year',
#        'month', 'Poll_No', 'DelimID', 'Position', 'Candidate', 'Sex', 'Party',
#        'Votes', 'Candidate_Type', 'Valid_Votes', 'Electors',
#        'Constituency_Name', 'Constituency_Type', 'Sub_Region', 'N_Cand',
#        'Turnout_Percentage', 'Vote_Share_Percentage', 'Deposit_Lost', 'Margin',
#        'Margin_Percentage', 'ENOP', 'pid', 'Party_Type_TCPD', 'Party_ID',
#        'last_poll', 'Contested', 'Last_Party', 'Last_Party_ID',
#        'Last_Constituency_Name', 'Same_Constituency', 'Same_Party', 'No_Terms',
#        'Turncoat', 'Incumbent', 'Recontest', 'Age', 'District_Name'],
#       dtype='object')

# %%
bjp_turncoat_gujrat_all = gujrat_from_1980_all.loc[(gujrat_from_1980_all['Party']=='BJP')&(gujrat_from_1980_all['Turncoat']==True),['State','Year','Constituency_Name','Party','Candidate','Last_Party','Position','Deposit_Lost']]
# Out:
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
bjp_turncoat_gujrat_all.groupby(['Party','Last_Party','Year'])['Last_Party'].count()
# Out:
# Party  Last_Party  Year
# BJP    AIRJP       2002     2
#                    2007     1
#        BJS         1980    24
#                    1985     3
#        BJSH        2012     1
#        BLD         1990     1
#        BSP         2009     1
#                    2017     1
#        CPI         1985     1
#        CPM         1995     1
#        GPP         2017     1
#        INC         1980     1
#                    1982     1
#                    1991     2
#                    1995     7
#                    1996     1
#                    1998     2
#                    2000     1
#                    2001     1
#                    2002     3
#                    2003     1
#                    2004     3
#                    2007     2
#                    2009     2
#                    2012     4
#                    2013     1
#                    2014     6
#                    2017    12
#        INC(I)      1990     1
#                    1998     1
# ...

# %%
inc_turncoat_gujrat_all = gujrat_from_1980_all.loc[(gujrat_from_1980_all['Party']=='INC')&(gujrat_from_1980_all['Turncoat']==True),['State','Year','Constituency_Name','Party','Candidate','Last_Party','Position','Deposit_Lost']]

# %%
inc_turncoat_gujrat_all.groupby(['Party','Last_Party','Year'])['Last_Party'].count()
# Out:
# Party  Last_Party  Year
# INC    AIRJP       2002    20
#                    2007     1
#                    2012     1
#        BJP         1981     1
#                    1982     1
#                    1984     1
#                    1985     1
#                    1988     1
#                    1990     1
#                    1991     2
#                    1995     3
#                    1996     1
#                    1997     1
#                    2000     2
#                    2002     4
#                    2003     1
#                    2004     2
#                    2007    11
#                    2009     5
#                    2010     1
#                    2011     1
#                    2012     2
#                    2013     5
#                    2014    11
#                    2016     2
#        BJS         1985     1
#        BNJ         2014     1
#        BNP         2007     1
#        BSP         2004     1
#        IN D        1981     1
# ...

# %%
maharastra_from_80 = pd.read_csv('maharastra_from_80.csv')
# Out:
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (18,37,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
bjp_turncoat_maharastra_all = maharastra_from_80.loc[(maharastra_from_80['Party']=='BJP')&(maharastra_from_80['Turncoat']==True),['State','Year','Constituency_Name','Party','Candidate','Last_Party','Position','Deposit_Lost']]

# %%
bjp_turncoat_maharastra_all.groupby(['Party','Last_Party','Year'])['Last_Party'].count()
# Out:
# Party  Last_Party  Year
# BJP    BBM         2004     1
#        BJS         1980     1
#                    1985     1
#                    1999     1
#        BSP         1999     1
#                    2009     1
#        GGP         2014     1
#        ICS         1990     1
#                    2009     1
#        INC         1980     1
#                    1985     1
#                    1990     1
#                    1999     2
#                    2004     1
#                    2009     2
#                    2014     6
#                    2019    11
#        INC(I)      1980     1
#        JD          1995     1
#                    1999     1
#        JD(S)       2004     2
#        JNP         1980    30
#                    1985     1
#                    1990     2
#        JS          1980     1
#                    1990     1
#        JSS         2014     1
#        LKSGM       2014     1
#        MNS         2014     1
#        NCP         2004     2
# ...

# %%
inc_turncoat_maharastra_all = maharastra_from_80.loc[(maharastra_from_80['Party']=='INC')&(maharastra_from_80['Turncoat']==True),['State','Year','Constituency_Name','Party','Candidate','Last_Party','Position','Deposit_Lost']]

# %%
inc_turncoat_maharastra_all.groupby(['Party','Last_Party','Year'])['Last_Party'].count()
# Out:
# Party  Last_Party  Year
# INC    BBM         2004     1
#                    2014     2
#        BBMS        1999     2
#        BJP         1995     1
#                    1999     1
#                    2014     1
#                    2019     4
#        BSP         1995     1
#                    2014     2
#        ICS         1990    35
#                    1995     1
#                    1998     1
#        ICS(SCS)    1995     1
#        INC(I)      1985    91
#                    1990    13
#                    1995     3
#                    1996     1
#                    1999     3
#                    2004     2
#        INC(U)      1985    11
#                    1990    11
#                    1995     1
#                    1999     2
#        JD          1990     1
#                    1995     6
#        JD(S)       2004     2
#        JNP         1985     2
#                    1990     2
#        JNP(JP)     1990     2
#        MUL         1999     1
# ...

# %%
rajasthan_from_80 = pd.read_csv('rajasthan_from_80.csv')
# Out:
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
bjp_turncoat_rajasthan_all = rajasthan_from_80.loc[(rajasthan_from_80['Party']=='BJP')&(rajasthan_from_80['Turncoat']==True),['State','Year','Constituency_Name','Party','Candidate','Last_Party','Position','Deposit_Lost']]

# %%
inc_turncoat_rajasthan_all = rajasthan_from_80.loc[(rajasthan_from_80['Party']=='INC')&(rajasthan_from_80['Turncoat']==True),['State','Year','Constituency_Name','Party','Candidate','Last_Party','Position','Deposit_Lost']]

# %%
inc_turncoat_rajasthan_all.groupby(['Party','Last_Party','Year'])['Last_Party'].count()
# Out:
# Party  Last_Party  Year
# INC    ABCD(A)     2008     1
#        AIIC(T)     1998     1
#        BJP         1985     1
#                    1990     3
#                    1998     2
#                    2003     2
#                    2008     1
#        BSP         2003     1
#                    2008     1
#                    2013     8
#        CPI         1993     1
#        INC(I)      1985    74
#                    1990    18
#                    1993     6
#                    2003     1
#        INC(U)      1985     1
#                    1990     2
#        JD          1993    15
#                    1998     5
#                    2003     1
#        JNP         1985     2
#                    1990     4
#        JNP(JP)     1993     1
#        JNP(SC)     1990     1
#        LD          2003     1
#        NCO         1985     1
#        NUZP        2018     1
#        RJVP        2003     1
#        SAP         2003     1
#        SP          1998     1
# ...

# %%
bjp_turncoat_rajasthan_all.groupby(['Party','Last_Party','Year'])['Last_Party'].count()
# Out:
# Party  Last_Party  Year
# BJP    BJS         1980     5
#                    1985     2
#                    1990     1
#                    1998     1
#                    2013     1
#        BJSH        2013     1
#        BSP         2008     1
#                    2013     2
#        CPI         2003     1
#        DDP         2013     1
#        ICJ         1993     1
#        ICS(SCS)    1993     1
#        INC         1980     1
#                    1985     2
#                    1993     1
#                    1998     8
#                    2003     1
#                    2008     3
#                    2013     3
#                    2018     3
#        INC(I)      1980     1
#                    1985     1
#                    1993     1
#        INC(U)      1985     1
#        INLD        2008     4
#                    2013     1
#        JD          1993    15
#                    1998     6
#                    2003     2
#        JD(P)       1998     1
# ...

# %%
mp_from_80 = pd.read_csv('mp_from_80.csv')
# Out:
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (13,18,37,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
inc_turncoat_mp_all = mp_from_80.loc[(mp_from_80['Party']=='INC')&(mp_from_80['Turncoat']==True),['State','Year','Constituency_Name','Party','Candidate','Last_Party','Position','Deposit_Lost']]

# %%
bjp_turncoat_mp_all = mp_from_80.loc[(mp_from_80['Party']=='BJP')&(mp_from_80['Turncoat']==True),['State','Year','Constituency_Name','Party','Candidate','Last_Party','Position','Deposit_Lost']]

# %%
bjp_turncoat_mp_all.groupby(['Party','Last_Party','Year'])['Last_Party'].count()
# Out:
# Party  Last_Party  Year
# BJP    AD          2008     1
#        AJBP        2003     1
#                    2013     1
#        BJS         1980     6
#                    1985     6
#                    1990     3
#                    2003     1
#        BJSH        2013     3
#        BSP         2008     2
#                    2018     3
#        CPI         1985     1
#                    1998     1
#                    2003     1
#        DDP         1993     1
#        GGP         1998     1
#        INC         1980     3
#                    1985     1
#                    1990     1
#                    1993     2
#                    1998     4
#                    2003     5
#                    2008     5
#                    2018     3
#        INC(I)      2013     1
#        INC(U)      1985     1
#        JD          1993     3
#                    1998     2
#                    2003     3
#        JNP         1980    62
#                    1985     6
# ...

# %%
inc_turncoat_rajasthan_all.groupby(['Party','Last_Party','Year'])['Last_Party'].count()
# Out:
# Party  Last_Party  Year
# INC    ABCD(A)     2008     1
#        AIIC(T)     1998     1
#        BJP         1985     1
#                    1990     3
#                    1998     2
#                    2003     2
#                    2008     1
#        BSP         2003     1
#                    2008     1
#                    2013     8
#        CPI         1993     1
#        INC(I)      1985    74
#                    1990    18
#                    1993     6
#                    2003     1
#        INC(U)      1985     1
#                    1990     2
#        JD          1993    15
#                    1998     5
#                    2003     1
#        JNP         1985     2
#                    1990     4
#        JNP(JP)     1993     1
#        JNP(SC)     1990     1
#        LD          2003     1
#        NCO         1985     1
#        NUZP        2018     1
#        RJVP        2003     1
#        SAP         2003     1
#        SP          1998     1
# ...

# %%
bjp_turncoat_mp_all['State'] = 'MP'

# %%
bjp_turncoat_gujrat_all['State'] = 'Gujrat'

# %%
bjp_turncoat_maharastra_all['State'] = 'Maharastra'

# %%
bjp_turncoat_rajasthan_all['State'] = 'Rajasthan'

# %%
wb77_21 = pd.read_csv('wb_from_77_to_21.csv')

# %%
bjp_turncoat_wb_all = wb77_21.loc[(wb77_21['Party']=='BJP')&(wb77_21['Turncoat']==True),['Year','Constituency_Name','Party','Candidate','Last_Party','Position','Deposit_Lost']]

# %%
inc_turncoat_wb_from_77 = wb77_21.loc[(wb77_21['Party']=='INC')&(wb77_21['Turncoat']==True),['Year','Constituency_Name','Party','Candidate','Last_Party','Position','Deposit_Lost']]

# %%
bjp_turncoat_wb_all.insert(0,'State','WB')

# %%
up_ac_from_77 = pd.read_csv('up_ac_from_77.csv')

# %%
bjp_turncoat_up_all = up_ac_from_77.loc[(up_ac_from_77['Party']=='BJP')&(up_ac_from_77['Turncoat']==True),['Year','Constituency_Name','Party','Candidate','Last_Party','Position','Deposit_Lost']]

# %%
bjp_turncoat_up_all.groupby(['Party','Last_Party','Year'])['Last_Party'].count()
# Out:
# Party  Last_Party  Year
# BJP    ABHM        2007     1
#        AD          2007     1
#                    2012     3
#                    2017     1
#        ADAL        2017     1
#        AIIC(T)     2017     1
#        ASP         2017     1
#        BHABHAPA    2017     1
#        BHJS        1996     1
#        BJS         1980    32
#                    1985    12
#                    1989     3
#                    1991     7
#                    1993    10
#                    1996     4
#        BKD         1980     1
#                    2007     1
#        BKKGP       2012     1
#        BMF         2017     1
#        BMUP        2017     3
#        BSCP        2017     1
#        BSP         2002     8
#                    2004     2
#                    2007     4
#                    2008     1
#                    2012     5
#                    2017    39
#        BSRD        2017     1
#        CPI(ML)     2017     1
#        CPI(ML)(L)  2017     1
# ...

# %%
inc_turncoat_up_all = up_ac_from_77.loc[(up_ac_from_77['Party']=='INC')&(up_ac_from_77['Turncoat']==True),['Year','Constituency_Name','Party','Candidate','Last_Party','Position','Deposit_Lost']]

# %%
inc_turncoat_up_all.groupby(['Party','Last_Party','Year'])['Last_Party'].count()
# Out:
# Party  Last_Party  Year
# INC    ABHM        2007     1
#        ABLTC       2002     1
#                    2012     1
#        ABLTP       2017     1
#        AD          2007     1
#                    2012     2
#                    2017     1
#        AIIC(T)     2002     1
#                    2007     1
#        ASP         2007     1
#        AYP         2017     1
#        BJP         1985     1
#                    1996     2
#                    2002     6
#                    2004     2
#                    2007     9
#                    2008     1
#                    2012     4
#                    2017     5
#        BJS         1977     2
#                    1985     1
#                    1989     2
#        BKD         1977    15
#                    1985     2
#                    1991     3
#                    1993     2
#                    2007     1
#        BSP         1991     1
#                    2002     5
#                    2004     1
# ...

# %%
bjp_turncoat_major_state = bjp_turncoat_gujrat_all.append([bjp_turncoat_maharastra_all,bjp_turncoat_mp_all,bjp_turncoat_rajasthan_all,bjp_turncoat_up_all,bjp_turncoat_wb_all])
# Out:
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
bjp_turncoat_major_state.groupby(['State','Party','Last_Party','Year'])['Last_Party'].count().loc[['Gujrat','UP','MP','WB','Maharastra','Rajasthan']]
# Out:
# State      Party  Last_Party  Year
# Gujrat     BJP    AIRJP       2002     2
#                               2007     1
#                   BJS         1980    24
#                               1985     3
#                   BJSH        2012     1
#                   BLD         1990     1
#                   BSP         2009     1
#                               2017     1
#                   CPI         1985     1
#                   CPM         1995     1
#                   GPP         2017     1
#                   INC         1980     1
#                               1982     1
#                               1991     2
#                               1995     7
#                               1996     1
#                               1998     2
#                               2000     1
#                               2001     1
#                               2002     3
#                               2003     1
#                               2004     3
# ...

# %%
bjp_turncoat_major_state.reset_index(drop='index',inplace=True)

# %%
national_party = ['AITC','BJP','INC','BSP','NCP','CPI','CPM']

# %%
bjp_turncoat_major_state_national_party = bjp_turncoat_major_state[bjp_turncoat_major_state['Last_Party'].isin(national_party)]

# %%
bjp_turncoat_major_state_national_party
# Out:
#                              Candidate Constituency_Name Deposit_Lost  \
# 1                            S.G.MANJI            JODIYA           no
# 23          RANA MANHARSINH NINDRASINH            SHEHRA          yes
# 42           DHODIA BALUBHAI VESTABHAI           BARDOLI          yes
# 49                       T.H.DESAIBHAI            BORSAD           no
# 50                        R.U.AMIRSINH             VAGRA           no
# 52           PATEL MOHANBHAI LALJIBHAI            UPLETA           no
# 53           GORIA JESABHAI MARKHIBHAI        KHAMBHALIA           no
# 58     GUMANSINHJI VIRAMSINHJI VAGHELA            DEODAR           no
# 59          SANGADA KALUBHAI VELGIBHAI             LIMDI           no
# 61      CHAUHAN PRABHATSINH PRATAPSINH             KALOL           no
# 65         Jeswani Durgaben Khushi Ram            Nadiad           no
# 66                    ARJUNSINH RATHVA            JETPUR           no
# ...

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=bjp_turncoat_major_state_national_party,x='Last_Party',hue='Year')
plt.legend(loc='upper right')
sns.set(font_scale=5)
plt.style.use('seaborn')
plt.show()

# %%
year_range = [1979,1998,2014,2022]

# %%
year_names = ['1979-1998','1998-2014','2014-2021']

# %%
bjp_turncoat_major_state_national_party['Year_Distribution'] = pd.cut(bjp_turncoat_major_state_national_party['Year'],bins=year_range,labels=year_names)
# Out:
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=bjp_turncoat_major_state_national_party,x='Last_Party',hue='Year_Distribution')
plt.legend(loc='upper right')
sns.set(font_scale=15)
plt.style.use('seaborn')
plt.show()

# %%
inc_turncoat_gujrat_all['State'] = 'Gujrat'

# %%
inc_turncoat_maharastra_all['State'] = 'Maharastra'

# %%
inc_turncoat_mp_all['State'] = 'MP'

# %%
inc_turncoat_rajasthan_all['State'] = 'Rajasthan'

# %%
inc_turncoat_up_all['State'] = 'UP'

# %%
inc_turncoat_wb_from_77['State'] = 'WB'

# %%
inc_turncoat_major_state = inc_turncoat_gujrat_all.append([inc_turncoat_maharastra_all,inc_turncoat_mp_all,inc_turncoat_mp_all,inc_turncoat_rajasthan_all,inc_turncoat_up_all,inc_turncoat_wb_from_77])
# Out:
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
inc_turncoat_major_state
# Out:
#                                                Candidate Constituency_Name  \
# 46                                            M.J.G.BHAI            LIMBDI
# 119                                        R.K.VALJIBHAI            JETPUR
# 480                                             B.JUMANI            NARODA
# 520                                       A.R.BHAVSINHJI           MEHSANA
# 1072                                 PATEL HARILAL NANJI             RAPAR
# 1101                       JIVUBHABHAI GHELUBHABHAI ZALA            HALVAD
# 1112                               SARDAVA JIVRAJ THOBAN             MORVI
# 1120                 PIRZADA MANZURHUSSEIN ABDUL MUTALIB          WANKANER
# 1154                       SORATHIYA POPATBHAI LAKHABHAI            GONDAL
# 1175                          BHIMANI DAYABHAI DEVSIBHAI            JODIYA
# 1215                       LEELABEN GAURISHANKER TRIVEDI            DWARKA
# ...

# %%
inc_turncoat_major_state_national_party = inc_turncoat_major_state[inc_turncoat_major_state['Last_Party'].isin(national_party)]

# %%
inc_turncoat_major_state_national_party.reset_index(drop='index',inplace=True)

# %%
inc_turncoat_major_state_national_party['Year_Distribution'] = pd.cut(inc_turncoat_major_state_national_party['Year'],bins=year_range,labels=year_names)
# Out:
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=inc_turncoat_major_state_national_party,x='Last_Party',hue='Year_Distribution')
plt.legend(loc='upper right')
sns.set(font_scale=15)
plt.style.use('seaborn')
plt.show()

# %%
bjp_turncoat_major_state_national_party['Year_Distribution'].replace('1979-1998','1980-1998',inplace=True)
# Out:
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\core\generic.py:6586: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
bjp_turncoat_major_state_national_party.groupby(['State','Year_Distribution','Last_Party'])['Last_Party'].count().unstack().replace(np.nan,0).astype(int)#.to_excel('bjp_turncoat_major_state_national_party.xlsx')
# Out:
# Last_Party                    AITC  BSP  CPI  CPM  INC  NCP
# State      Year_Distribution
# Gujrat     1980-1998             0    0    1    1   14    0
#            1998-2014             0    1    0    0   24    1
#            2014-2021             0    1    0    0   12    0
# MP         1980-1998             0    0    2    0   11    0
#            1998-2014             0    2    1    0   10    0
#            2014-2021             0    3    0    0    3    0
# Maharastra 1980-1998             0    0    0    0    3    0
#            1998-2014             0    2    0    0   11   14
#            2014-2021             0    0    0    0   11    6
# Rajasthan  1980-1998             0    0    0    0   12    0
#            1998-2014             0    3    1    0    7    0
#            2014-2021             0    0    0    0    3    0
# WB         1980-1998             0    0    0    1    4    0
#            1998-2014             1    1    0    0    2    0
# ...

# %%
inc_turncoat_major_state_national_party['Year_Distribution'].replace('1979-1998','1980-1998',inplace=True)

# %%
bjp_turncoat_major_state_national_party.groupby('Last_Party')['Last_Party'].count()
# Out:
# Last_Party
# AITC     14
# BSP      72
# CPI       5
# CPM       9
# INC     195
# NCP      21
# Name: Last_Party, dtype: int64

# %%
inc_turncoat_major_state_national_party.groupby(['State','Year_Distribution','Last_Party'])['Last_Party'].count().unstack().replace(np.nan,0).astype(int)
# Out:
# Last_Party                    AITC  BJP  BSP  CPI  CPM  NCP
# State      Year_Distribution
# Gujrat     1980-1998             0   13    0    0    0    0
#            1998-2014             0   45    1    0    0    1
#            2014-2021             0    2    0    0    0    0
# MP         1980-1998             0    6    2    0    2    0
#            1998-2014             0   10   10    0    0    2
#            2014-2021             0    0    8    0    0    0
# Maharastra 1980-1998             0    1    1    0    0    0
#            1998-2014             0    2    2    0    0    5
#            2014-2021             0    4    0    0    0    1
# Rajasthan  1980-1998             0    6    0    1    0    0
#            1998-2014             0    3   10    0    0    0
# UP         1980-1998             0    3    1    2    0    0
#            1998-2014             0   22   28    0    0    1
#            2014-2021             0    5    8    0    0    0
# ...

# %%
inc_turncoat_major_state_national_party.groupby('Last_Party')['Last_Party'].count()
# Out:
# Last_Party
# AITC     13
# BJP     123
# BSP      71
# CPI       3
# CPM       5
# NCP      13
# Name: Last_Party, dtype: int64
